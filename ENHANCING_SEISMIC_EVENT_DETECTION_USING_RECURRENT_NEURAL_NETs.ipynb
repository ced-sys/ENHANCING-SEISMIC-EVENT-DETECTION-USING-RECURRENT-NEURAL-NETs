# %% [markdown]
# <a href="https://colab.research.google.com/github/ced-sys/ENHANCING-SEISMIC-EVENT-DETECTION-USING-RECURRENT-NEURAL-NETs/blob/main/ENHANCING_SEISMIC_EVENT_DETECTION_USING_RECURRENT_NEURAL_NETs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install dependencies
# ##Purposes
# This code installs Python Libraries necessary for the project for machine learnin, signal processing and data visualization
#
# #Libraries
# 1. Tensorflow
# An open source machine learning framework for creating and deploying deep learning mmodels
#
# #Obspy
# Python library designed for processing and analysing seismological data.
#
# It provides tools fro reading, writing and processing waveform data and supports seismic event analysis.
#
# #Matplotlib
# Matplotlib is a plotting library used for creating static, interactive and animated visualizations.
#
# It helps visualize seismic waveforms, and machine learning model outputs.
#
# #Scikit-learn
# Machine learning library that provides tools for classification and providing the metrics of scoring the model.
#
# It is also used in feature engineering.

# %%
# !pip install tensorflow obspy matplotlib scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: obspy in /usr/local/lib/python3.12/dist-packages (1.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.12/dist-packages (from obspy) (1.16.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from obspy) (5.4.0)
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.12/dist-packages (from obspy) (1.4.54)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from obspy) (4.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<2->obspy) (3.2.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# # Import Libraries and modules
# ## Core libraries
# `numpy` and `matplotlib.pyplot`: For numerical operations and data visualization.
# `os`: For file and directory management.
#
# ## Seismology tools
# `obspy`: Manages seismic data, including date/time handling (`UTCDateTime`), data streams (`Stream`, `Trace`), and fetching data from online servers (`Client`). It also includes signal processing methods like `classic_sta_lta` for detecting seismic events and `bandpass` for filtering.
#
# ## Machine Learning Tools
# `sklearn`: Provides tools for data splitting (`train_test_split`, `StratifiedKFold`), scaling (`MinMaxScaler`, `StandardScaler`), and performance evaluation metrics (precision, recall, F1, confusion matrix, ROC curve)
#
# ##Deep Learning Tools
# `tensorflow.keras`: For creating and training RNN models. Key components include:
#
# *   **Model Building**: `Sequential`
# *   **RNN Layers**: `LSTM`, `GRU`, `SimpleRNN`, `Bidirectional`
# *   **CNN Layers**: `Conv1D`, `MaxPooling1D`
# *   **Regularization and Optimization**: `l2`, `Adam`
# *   **Training Callbacks**: `EarlyStopping`, `ReduceLROnPlateau`, `ModelCheckpoint`.
#
# ##Visualization Tools
# `seaborn`: For advanced statistical plotting.
# `tensorflow`: Core library for building and deploying machine learning models.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from obspy import UTCDateTime, Stream, Trace
from obspy.clients.fdsn import Client
from obspy.signal.trigger import classic_sta_lta
from obspy.signal.filter import bandpass
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (LSTM, Dense, Dropout, BatchNormalization,
                                     Bidirectional, SimpleRNN, GRU, Conv1D, MaxPooling1D)
from tensorflow.keras.callbacks import(
    EarlyStopping, ReduceLROnPlateau,
    ModelCheckpoint
)

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    classification_report, confusion_matrix,
    accuracy_score, roc_auc_score, roc_curve,
    precision_recall_curve
)
import seaborn as sns
import tensorflow as tf

# %% [markdown]
# # Create output directory
# The function `create_output_directory()` creates a directory named `seismic_detection_outputs` for saving plots, models or any other project related files.
#
# ##Define directory name
# `base_dir='seismic_detection_outputs'`sets the directory name
#
# ##Create directory
# `os.makedirs(base_dir, exist_ok=True)`creates the directory if it doesn't already exist. The `exist_ok=True` parameter prevents errors if the directory already exists.
#
# ##Return Directory Path
# The function returns the directory path `base_dir` or later use in saving files.

# %%
def create_output_directory():
  """Create a directory for saving plots and models"""
  base_dir='seismic_detection_outputs'
  os.makedirs(base_dir, exist_ok=True)
  return base_dir

# %% [markdown]
# # Fetch IRIS data
# `network`: Seismic network code
#
# `station`: Seismic station code
#
# `location`: Station location identifier
#
# `channel`:Channel code for seismic data
#
# `origin_time`: Start time for fetching, in UTC format
#
# `duration`: Length of time (in seconds) to fetch data after `origin_time`.
#
# ##Function workflow
# 1. **Initialize Client**: `client=Client("IRIS")` sets up a connection to the IRIS database.
#
# 2. **Define time range**: `start_time=origin_time` sets the starting point. `end_time=origin_time+duration` calculates the ending point.
#
# 3. **Fetch Seismic data**: `stream=client.get_waveforms()` fetches seismic waveform data based on the provided parameters.
#
# 4. **Handle errors**: If the data fetching process fails, the function prints an error message and returns `None`.
#
# ##Return Value
# Returns the `stream` object containing the seismic waveform data if successful or `None` if an error occurs.

# %%
def fetch_iris_data(network, station, location, channel, origin_time, duration=120):
  """Fetch Seismic data from the IRIS database"""
  try:
    client=Client("IRIS")
    start_time=origin_time
    end_time=origin_time+duration

    stream=client.get_waveforms(network, station, location, channel, start_time, end_time)
    return stream
  except Exception as e:
    print(f"Error fetching data from IRIS:{str(e)}")
    return None

# %% [markdown]
# # Generate Synthetic Data
# The function creates synthetic seismic waveform data, including background noise and multiple seismic-like events.
#
# ##Function parameters
# `num_samples`: Total number of samples in the synthetic signal.
#
# `sample_rate`: Number of samples per second.
#
# `event_duration`: Length of each seismic event in seconds.
#
# `noise_level`: Standard deviation of the background noise.
#
# `num_events`: Maximum number of events to generate (default is 3).
#
# ##Function workflow
# 1. **Initialize variables**:
#
# `time`: Array representing the time points of the synthetic signal.
#
# `background`: Random nise with mean 0 and standard deviation `noise_level`.
#
# `events`: Zero-initialized array for storing events.
#
# `event_locations`: List to store start and end indices of generated events.
#
#
# 2. **Generate seismic events**:
# Loop through a random number of events (between 1 and `num_events`).
#
# **Event location**:Randomly select an event start index between 1/8 and 7/8 of the signal to avoid edge effects.
#
# Calculate the event's and index based on `event_duration`.
#
# **Event Characetristics**: Randomly generate frequencies (`freq1`, `freq2`), amplitudes (`amp1`, `amp2`) and decay rates (`decay1`, `decay2`) for two sine wave components.
#
# Create the event as a decaying sinusoidal combination to simulate realistic seismic waveforms.
#
# **Insert Event**: Add the generated event to the corresponding range in the `events` array.
#
# 3.  **Combine Background and Events**: add `background` and `events` to create the final synthetic data.
#
# ##Return Values
# `data`: Combined synthetic waveform (background + events)
# `events`: Isolated events without noise.
# `event_locations`: List of tuples indicating event start and end indices.

# %%
def generate_synthetic_data(num_samples, sample_rate, event_duration, noise_level, num_events=3):
  """Generate synthetic data with multiple events"""
  time=np.arange(num_samples)/ sample_rate
  background=np.random.normal(0, noise_level, num_samples)
  events=np.zeros(num_samples)
  event_locations=[]

  for _ in range(np.random.randint(1, num_events+1)):
    event_start=np.random.randint(num_samples // 8, num_samples*7//8)
    event_end=event_start + int(event_duration*sample_rate)
    event_locations.append((event_start, event_end))

    #Create more realistic events with multiple frequency components
    freq1=np.random.uniform(3,8)
    freq2=np.random.uniform(10, 20)
    amp1=np.random.uniform(1.0, 2.0)
    amp2=np.random.uniform(0.5, 1.5)
    decay1=np.random.uniform(0.1, 0.3)
    decay2=np.random.uniform(0.2, 0.4)

    event_time=time[event_start:event_end]-time[event_start]
    event=(
        amp1*np.sin(2*np.pi*freq1*event_time)*np.exp(-event_time/decay1)+
        amp2*np.sin(2*np.pi*freq2*event_time)*np.exp(-event_time/decay2)
    )
    events[event_start:event_end]=event
  data=background+events
  return data, events, event_locations

# %% [markdown]
# # Process Stream
# This function performs advanced preprocessing on a seismic data stream to enhance signal quality and detect seismix events using the STA/LTA method.
#
# ## Function parameters
# `stream`: The seismic data stream to process.
# `freqmin`: Minimum frequency for bandpass filtering (default is 0.5 Hz).
# `freqmax`: Maximum frequency fo bandpass filtering (default is 20 Hz).
#
# ## Processing Workflow
# 1. **Create a copy**: `processed_stream=stream.copy()` avoids modifying the original data.
#
# 2. **Preprocessing Steps**:
#
# `detrend('linear')`:Removes linear trends from the data
#
# `taper(max_percentage=0.1)`: Applies a 10% taper to reduce edge effects.
#
# `filter ('bandpass'...)`: Applies a 6th-order zero-phase bandpass filter to isolate relevant seismic frequencies.
#
# 3. **STA/LTA Trigger Calculation**:
#
# Extract the first trace: `trace=processed_stream[0]`
#
# Apply the STA/LTA algorithm `classic_sta_lta(trace.data, int(0.5*trace.stats.sampling_rate), int(10*trace.stats.sampling_rate))` computed the characteristic function `cft`.
#
# The short-term average (STA) window is 0.5 seconds.
#
# The long-term average (LTA) window is 10 seconds.
#
# ##Return values
# `processed_stream`: The preprocessed seismic stream.
# `cft`: The STA/LTA characteristic function for event detection.

# %%
def process_stream(stream, freqmin=0.5, freqmax=20):
  """Enhanced stream processing with more robust filtering"""
  processed_stream=stream.copy()
  processed_stream.detrend('linear')
  processed_stream.taper(max_percentage=0.1)
  processed_stream.filter('bandpass', freqmin=freqmin, freqmax=freqmax,
                          corners=6, zerophase=True)

  #Add STA/LTA trigger for additional event detection
  trace=processed_stream[0]
  cft=classic_sta_lta(trace.data, int(0.5*trace.stats.sampling_rate),
                      int(10*trace.stats.sampling_rate))
  return processed_stream, cft

# %% [markdown]
# # Enhanced windows
# The function generates labelled data windows with advanced feature engineering for seismic event prediction. It uses synthetic event location, STA/LTA triggers and statistical anomaly detection for labelling.
#
# ##Function Parameters
# `data`: The input seismic data array.
#
# `window_size`: Number of samples per window.
#
# `step`: Step size for moving the window along the data.
#
# `event_locations`: List of event start and end indices from synthetic data (optional).
#
# `cft`: STA/LTA characteristic function for event detection (optional)
#
#
# ##Inner Function
# `detect_event_by_trigger(window_start, window_end, cft)`
# Checks if the maximum STA/LTA value within a window exceeds a threshold (3.0).
#
# Returns `True` if an event is detected, otherwise `False`.
#
# ##Processing Workflow
#
# 1. **Initialize Lists**:
# `windows=[]`: To store windowed features.
#
# `labels=[]`: To store corresponding labels.
#
# 2. **Loop through data**:
#
# Sliding window from start to end of `data` with the specified `step`.
#
# Extract a data `window` of size `window_size`.
#
# 3. **Feature Engineering**:
#
# **Time Domain Features**:
# *  Raw signal (`window`).
# *  Absolute amplitude (`np.abs(window)`)
# *  First and second deravitives (`np.gradient(window)`), `np.gradient(np.gradient(window))`)
# *  Log-transformed absolute amplitude (`np.log1p(np.abs(window))`).
#
# **Frequency Domain features**
# Compute the real part of the FFT (`np.fft.fft(window)`), keeping half of the spectrum.
#
# Pad the FFt result to match `window_size`.
#
# Stack all features into `window_features`.
#
# 4. **Labelling logic**:
# Initialize `label=0` (no event detected).
#
# **Synthetic event check**
# Check if window overlaps with any event in `event_locations`.
#
# **STA/LTA Trigger check**:
# If no synthetic event is found, use STA/LTA detection.
#
# **Anomaly Detection (Fallback)**:
# If still no event, compare the window's mean absolute value to the data's standard deviation.
#
# Assign `label=1`if the mean exceeds 2.5 times the standard deviation,
#
# 5. **Store results**
#
# Append `window_features` to `windows`.
# Append `label` to `labels`.
#
# ##Return Values
#
# `windows`: A 2D array of windowed features for model input.
# `labels`: Corresponding labels (0 for no event, 1 for event).

# %%
def create_enhanced_windows(data, window_size, step, event_locations=None, cft=None):
  """Create window with advanced feature engineering and labelling"""
  windows=[]
  labels=[]

  #add STA/LTA trigger-based event detection if available
  def detect_event_by_trigger(window_start, window_end, cft=None):
    if cft is not None:
      window_cft=cft[window_start:window_end]
      return np.max(window_cft)>3.0 #Adjust threshold as needed
    return False

  for i in range(0, len(data)-window_size+1, step):
    window=data[i:i+window_size]
    freq_features=np.fft.fft(window)[:window_size//2].real
    freq_features_padded=np.pad(freq_features, (0, window_size-len(freq_features)), 'constant')

    #Advanced feature engineering
    window_features=np.column_stack([
        window, #Raw signal
        np.abs(window), #Absolute amplitude
        np.gradient(window), #First deravitive
        np.gradient(np.gradient(window)), #Second derivative
        np.log1p(np.abs(window)), #Log of absolute amplitude
        freq_features_padded, #Padded frequency domain features
    ])

    #Labelling logic with multiple detection methods
    label=0
    if event_locations:
      #Check if window contains an event from synthetic data
      for start, end in event_locations:
        if (i<=end and i +window_size >= start):
          label=1
          break

    #Additional event detection using STA/LTA
    if label==0 and detect_event_by_trigger(i, i +window_size, cft):
      label=1

    #Fall back: statistical anomaly detection
    if label==0:
      window_mean=np.abs(window).mean()
      data_std=np.abs(data).std()
      label=1 if window_mean> data_std *2.5 else 0

    windows.append(window_features)
    labels.append(label)
  return np.array (windows), np.array(labels)

# %% [markdown]
# # Build advanced RNN model
# The function defines a deep learning model combining Convolutional Neural Netwroks (CNNs) and Recurrent Neural Networks (RNNs) for seismic event prediction. This hybrid architecture leverages both spatial and temporal feature extraction techniques.
#
# ##Function Parameter
# `input_shape`: Shape of the input data, typically `(window_size, num_features)`.
#
# ##Model Architecture:
#
# 1. **Convolutional Layer for Feature Extraction**:
# `Conv1D(64, kernel_size=5, activation='relu')`: Extracts spatial features with 64 filter and a kernel size of 5.
#
# `MaxPooling1D(pool_size=2)`: Reduces the dimensionality be half.
#
# `BatchNormaliation()`: Normalizes the activations to stabilie and accelerate trainig.
#
# 2. **Recurrent Layers for Temporal Dependenices**:
# `Bidirectional(GRU(128, return_sequences=True))`: Captures long-term dependencies in both forward and backward directions.
# `return_sequences=True` enables stacking further RNN layers.
#
# `BatchNormalization()` and `Dropout(0.4)`: Improves training stability and prevents overfitting.
#
# `Bidirectional(LSTM(96, return_sequences=True))`: Similar to the GRU layer but with increased model complexity.
#
# `SimpleRNN(64)`: Adds a final RNN layer to extract additional sequential patterns.
#
# 3. **Dense Layers for Classification**:
# `Dense(128, activation='relu)`: fully connected layer with ReLU activation and L2 regularization
#
# `BatchNormalization()` & `Dropout(0.3)`: Stabilizes training and reduces overfitting.
#
# `Dense(64, activation='relu)`: Second fully connected layer for deeper feature integration.
#
# `Dense(1, activation='sigmoid')`: Final output layer for binary classification (seismic event or no event).
#
# ##Optimizer and Compilation
# **Optimizer**: `Adam(learning_rate=0.0003, beta_1=0.9, beta_2=0.999)` is configured for more aggressive optimization with a low learning rate.
#
# **Loss function**: `binary_crossentropy` is used for binary classification task.
#
# **Metrics**: `accuracy`,`Precision()` and `Recall()` monitor the model's performance comprehensively.
#
# ##Return Value:
# The compiled model is returned, rady for training and evaluation

# %%
def build_advanced_rnn_model(input_shape):
  """Enhanced RNN model with CNN-RNN hybrid architecture"""
  model= Sequential([
      #Convolutional layer for feature extraction
      Conv1D(64, kernel_size=5, activation='relu', input_shape=input_shape,
             kernel_regularizer=l2(0.001)),
      MaxPooling1D(pool_size=2),
      BatchNormalization(),


  #Bidirectional RNN layers with increased complexity
  Bidirectional(GRU(128, return_sequences=True,
                    kernel_regularizer=l2(0.001))),
  BatchNormalization(),
  Dropout(0.4),

  Bidirectional(LSTM(96, return_sequences=True,
                     kernel_regularizer=l2(0.001))),
  BatchNormalization(),
  Dropout(0.4),

  #Additional RNN layer
  SimpleRNN(64, kernel_regularizer=l2(0.001)),
  BatchNormalization(),
  Dropout(0.3),

  #Dense layers for classification with increased regularization
  Dense(128, activation='relu', kernel_regularizer=l2(0.002)),
  BatchNormalization(),
  Dropout(0.3),

  Dense(64, activation='relu', kernel_regularizer=l2(0.002)),
  Dense(1, activation='sigmoid')

  ])

  #More aggresive optimizer configuration
  optimizer=Adam(
      learning_rate=0.0003,
      beta_1=0.9,
      beta_2=0.999
  )

  model.compile(
      optimizer=optimizer,
      loss='binary_crossentropy',
      metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]

  )

  return model

# %% [markdown]
# # Train and evaluate the model
# This function trains and evaluates the RNN model using cross-validation, with various enhancements for model training, evaluation and performance tracking
#
# ##Function Parameters
# `X`: Input feature for training, shaped as `(num_samples, num_timesteps, num_features)`.
#
# `y`: Labels for the samples, either 0 (no event) or 1 (event).
#
# `base_dir`: directory to save model checkpoints, plots, and evaluation results.
#
# ##Function Workflow:
# 1. **Feature Scaling**:
# The function uses `StandardScaler() to scale the input features (`X`) to have a mean of 0 and a standard deviation of 1 for improved model performance.
#
# `X_scaled=scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)`reshapes and scales the input data accordingly.
#
# 2. **Cross-Validation setup**:
# **Stratified K-Fold Cross Validation**: `StratifiedKFold(n_splits=10)` ensures that each fold has a balanced distribution of classes (seismic event and no event).
#
# The cross-validation splits the data into 10 folds.
#
# 3. **Model training and evaluation**:For each fold:
#
# **Training and Validation split**: The data is divided into training (`X_train, y_train`) using the indices provided by `StratifiedKFold`.
#
# **Model Initialization**:
# The RNN model is re-initialized for each fold to avoid training from previous fold weights.
#
# **Callbacks**:
# Several callbacks are used for better training management:
# *  **EarlyStopping: Stops training if the validation loss doesn't improve after 20 epochs, restoring the best weights.
#
# *  **ReduceLROnPLateau**: Reduces the learning rate by a factor of 0.3 if the validation loss doesn't improve for 10 epochs.
#
# *  **ModelCheckpoint**: Svaes the best model based on the validation recall score.
#
# **Model training**:
# The model is trained for a maximum of 150 epochs with a batch size of 32. The `class_weight={0:1., 1:3.}` argument assigns more weight to the event class (class`1`), compensating for class imbalance.
#
# **Predictions and Metrics**:
# The model's predictions are made on the validation set, and binary classification is performed by thresholding the predicted probabilities at 0.5.
#
# Metrics calculated include:
# 1.  Accuracy
# 2.  Precision
# 3.  Recall
# 4. F1 score
# 5. AUC(Area Under the Curve)
#
# **Plots**:
# Several plots are generated for performance visualization:
# *  **ROC Curve**(`plot_roc_curve`)
# *  **Training history**(`plot_training_history`)
# *  **Confusion Matrix**(`plot_confusion_matrix`)
# *  **Precision-Recall Curve**(`plot_precision-recall_curve`)
#
# 4. **Cross-validation results**:
# After completing all the folds, the function prints the average cross-validation score for each metric (accuracy, precision, recall, F1 Score and AUC) with their standard deviations.
#
# ##Return values
# `model`: The trained model from the final fols, saved after training.
# `cv_scores`: A dictionary containing cross-validation scores for eac metric accuracy, precision, recall, F1 Score and AUC
#
# ##Key enhancements
# **Cross-Validation**: Using Stratified K-Fold ensures balabced training and testing sets.
#
# **Regularization**: includes L2 regularization, dropout, and batch normalization to improve generalization and avoid overfitting.
#
# **Class weighing**: More emphasis on detecting seismic events by applying stronger weight to class `1`.
#
# **Comprehensive Evaluation**: Tracks a variety of performance metrics, generates detailed reports and visualizes results through multiple plots.

# %%
def train_and_evaluate_model(X, y, base_dir):
  """Comprehensive model training with cross-validation"""
  #Use StandardScaler for better feature scaling
  scaler=StandardScaler()
  X_scaled=scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)

  #Stratified K-Fold cross validation with more splits
  kfold=StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

  #Tracking metrics
  cv_scores={
      'accuracy':[], 'precision':[],
      'recall':[], 'f1':[], 'auc':[]
  }

  #Model checkpoint directory
  model_dir=os.path.join(base_dir, 'best_models')
  os.makedirs(model_dir, exist_ok=True)

  for fold, (train_idx, val_idx) in enumerate(kfold.split(X_scaled, y), 1):
    print(f"\n=== Fold {fold}===")

    X_train, X_val=X_scaled[train_idx], X_scaled[val_idx]
    y_train, y_val=y[train_idx], y[val_idx]

    #Reset model for each fold
    model=build_advanced_rnn_model((X.shape[1], X.shape[2]))

    #Improved callbacks
    callbacks=[
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.3,
            patience=10,
            min_lr=1e-6
        ),
        ModelCheckpoint(
            filepath=os.path.join(model_dir, f'best_model_fold_{fold}.keras'),
            monitor='val_recall',
            mode='max',
            save_best_only=True
        )
    ]

    #Train model with more aggressive class weighting
    history=model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=150,
        batch_size=32,
        callbacks=callbacks,
        class_weight={0:1., 1: 3.}, #Stronger emphasis on event class
        verbose=1
    )

    #Predictions and evaluation
    predictions=model.predict(X_val).flatten()
    binary_predictions=(predictions >0.5).astype(int)

    #compute metriics
    accuracy=accuracy_score(y_val, binary_predictions)
    precision=precision_score(y_val, binary_predictions)
    recall=recall_score(y_val, binary_predictions)
    f1=f1_score(y_val, binary_predictions)
    auc=roc_auc_score(y_val, predictions)

    cv_scores['accuracy'].append(accuracy)
    cv_scores['precision'].append(precision)
    cv_scores['recall'].append(recall)
    cv_scores['f1'].append(f1)
    cv_scores['auc'].append(auc)

    #Print detailed classification report
    print("\nClassification Report:")
    print(classification_report(y_val, binary_predictions))

    #Plot ROC curve
    plot_roc_curve(y_val, predictions, base_dir, fold)
    plot_training_history(history, base_dir)
    plot_confusion_matrix(y_val, binary_predictions, base_dir)
    plot_precision_recall_curve(y_val, predictions, base_dir)

  #Print average cross-validation scores
  print("\n=== Cross-Validation Results ===")
  for metric, scores in cv_scores.items():
    print(f"{metric.capitalize()}: {np.mean(scores):.4f} (±{np.std(scores):.4f})")

  return model, cv_scores

# %% [markdown]
# # Plot Receiver Operating Characteristic
# The ROC curve visualizes the trade-off between the true positive rate and the false positive rate at different thresholds, helping evaluate the classifier's performance. A curve closer to the top-left corner indicates better performance.
#
# ## Function definition and inputs
# `y_true`: Actual labels (ground truth).
# `y_scores`: Predicted probabilities from the model.
# `base_dir`: Directory where the ROC curve image will be saved.
# `fold`: The current fold number in cross-validation.
#
# ##Compute ROC metrics
# `fpr, tpr, thresholds=roc_curve(y_true, y_scores):`
#
# `fpr`: False Positive Rate.
# `tpr`: True Positive Rate.
# `thresholds`: Decision thresholds used to compute `fpr` and `tpr`.
#
# ##Plot the ROC Curve
#
#
# *   Sets the figure size to 8*6 inches
# *   Plots the ROC curve using `fpr` and `tpr`.
# *   Adds a diagonal red dashed line representing a random classifier (baseline).
# *   Adjusts the axis limits for better visualization.
# *   Labels the axes and titles the plot.
# *   Adds a legend to distinguish the model from the baseline.
#
# ##Save the Plot
# *  Constructs the file path using `os.path.join`.
# *  Saves the plot as `roc_curve_fold_{fold}.png` in the specified directory.
# *  Closes the plot to free up memory and avoid overlapping features.

# %%
def plot_roc_curve(y_true, y_scores, base_dir, fold):
  """Plot and save ROC curve"""
  fpr, tpr, thresholds=roc_curve(y_true, y_scores)

  plt.figure(figsize=(8,6))
  plt.plot(fpr, tpr, color='blue', label='ROC curve')
  plt.plot([0,1], [0,1], color='red', linestyle='--', label='Random Classifier')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title(f'Receiver Operating Characteristic- Fold{fold}')
  plt.legend(loc='lower right')

  #Save plot
  plt.savefig(os.path.join(base_dir, f'roc_curve_fold_{fold}.png'))
  plt.close()

# %% [markdown]
# # Plot training history
# This function visualizes the training and validation performance metrics from the model's training from the model's training history and saves the generated plots as an image file.
#
# ##Function Definition and inputs
# `history`: Training history object returned by `model.fit()`.
# `base_dir`: Directory where the training metrics plot will be saved.
#
# ##Figure Initialization
# Sets the figure size to `15*10` inches.
#
# ##Subplot 1: Model Loss
# Plots training hand validation loss values from `history.history['loss']` and `history.history['val_loss']`.
#
# Labels the axis as "Epoch" and "Loss".
#
# Adds a title "Model Loss" and a legend to differentiate between training and validation loss.
#
# ##Subplot 2: Model Accuracy
# Plots training and validation accuravy from `history.history['accuracy']` and `history.history['val_accuracy']`.
#
# Labels the axes as 'Epoch' and "Accuracy".
#
# Adds a title "Model Accuracy" and a legend to sitinguish between training and validation accurcay.
#
# ##Layout adjustment and saving
# Uses `plt.tight_layout()` to optimize subplot spacing.
#
# Saves the figure as `training_metric.png` in the specifies `base_dir`.
#
# Closes the figure to prevent memory issues or overlapping plots.

# %%
def plot_training_history(history, base_dir):
  """Plot Training and validation metrics"""
  plt.figure(figsize=(15, 10))

  plt.subplot(2,2,1)
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title("Model Loss")
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend()

  plt.subplot(2,2,2)
  plt.plot(history.history['accuracy'], label='Training Accuracy')
  plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
  plt.title("Model Accuracy")
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend()

  plt.tight_layout()
  plt.savefig(os.path.join(base_dir, 'training_metric.png'))
  plt.close()

# %% [markdown]
# # Plot Confusion Matrix
# The function generates a heatmap of the confusion matrix from predicted and true labels,providing insight into the model's classification performance. The resulting plot is saved as an image file.
#
# ##Function definition and inputs
# `y_true`: Actual labels from the validation dataset.
#
# `y_pred`: Predicted labels generated by the model.
#
# `base_dir`: Directory where the confusion matrix plot will be saved.
#
# ##Compute Confusion Matrix
# Calss `confusion_matrix(y_true, y_pred)` to calculate the confusion matrix, which shows the number of correct and incorrect predictions for each class.
#
# ##Create Heatmap plot
# Initializes a plot of size 8*6 inches.
#
# Uses `sns.heatmap()` to create a heatmap visualization.
#
# `cm`: confusion matrix data.
#
# `annot=True`: Displays numeric values on the heatmap.
#
# `fmt=d` formats annotations as integers.
#
# `cmap=Blues`: Sets the heatmap color theme.
#
# `xticklabels` and `yticklabels`: Labels for predicted and true classes.
#
# ##Add titles and Labels
# Sets the plot title to "Confusion Matrix".
#
# Labels the x-axis as "Predicted Label."
#
# Labels the y-axis as "True Label."
#
# ##Save the plot
# Adjusts layout with `plt.tight_layout()` to avoid clipping.
#
# Saves the figure as `confusion_matrix.png` in `base_dir`.
#
# Closes the figure to prevent overlapping or memory issues.

# %%
def plot_confusion_matrix(y_true, y_pred, base_dir):
  cm=confusion_matrix(y_true, y_pred)
  plt.figure(figsize=(8,6))
  sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
              xticklabels=['No Event', 'Event'],
              yticklabels=['No Event', 'Event'])
  plt.title('Confusion Matrix')
  plt.xlabel('Predicted Label')
  plt.ylabel('True label')
  plt.tight_layout()
  plt.savefig(os.path.join(base_dir, 'confusion_matrix.png'))
  plt.close()

# %% [markdown]
# # Plot Precision Recall Curve
# The function generates a Precision-Recall Curve which is a graphical representation of the tradeoff between precision and recall for different classification thresholds. It saves the plot as an image file in the specified directory.
#
# ##Parameters
# `y_true`: True binary labels of the dataset(0, 1), indicating whether a data point belongs to the positive case.
#
# `y_scores`: Predicated probabilities or scores are assigned to the positive class by the classifier. These scores are used to compute precision adn recall at various thresholds.
#
# `base_dir`: Directory path where the generated plot will be saved.
#
# ##Functionality
# 1. **Computing Precision and Recall**
# The function uses `precision_recall_curve` from `sklearn.metrics` to compute precision and recall values over a range of thresholds.
#
# The function also outputs thresholds
#
# 2. **Plotting the curve**
# A new figure is created with a size of `8*6` inches for clear visualization.
#
# Precision is plotted on the y-axis and recall is plotted on the x-axis. A blue line represents the curve.
#
# Labels and a legend are added to make the plot informative.
#
# 3. **Adjusting the Layout**
# The `plt.tight_layout()` method ensures that the elements of the plot are arranged neatly without overlap.
#
# 4. **Saving the Plot**
# The plot is saved as an image named `precision_recall_curve.png` in the specified `base_dir` using `os.path.join` for robust path handling.
#
# 5. **Closing the plot**
# `plt.close()` is called to release resources and avoid displaying of the figure.

# %%
def plot_precision_recall_curve(y_true, y_scores, base_dir):
  precision, recall, _=precision_recall_curve(y_true, y_scores)

  plt.figure(figsize=(8,6))
  plt.plot(recall, precision, color='blue', label='Precision-Recall Curve')
  plt.title('Precision-Recall curve')
  plt.xlabel('Recall')
  plt.ylabel('Precision')
  plt.legend()
  plt.tight_layout()
  plt.savefig(os.path.join(base_dir, 'precision_recall_curve.png'))
  plt.close()

# %% [markdown]
# # Plot Seismic Data
# The function is designed to visualize and compare seismi data from three diffeerent sources, the real seismic data, synthetic data and a combination of both. It generates a side-by-side comparison of these data sources in the form of a plot and saves the pot as an image file
#
# ##Parameters
# `real_data`: The actual seismic data from Indonesian station.
#
# `synthetic_data`: Simulated seismic data generated through modelling or computational techniques.
#
# `combined_data`: Data resulting from the combination of real and synthetic data, often used to analyze correlation or validate models.
#
# `base_dir`: The directory path where the plot image will be saved.
#
# ##Functionality
# 1. **Figure Setup**
# The function creates a `matplotlib` figure with a size of `15*10` inches, providing ample space for three subplors stacked vertically.
#
# 2. **Subplots for Visualization**
# First Subplot: Plots the `real_data` as "Real Seismic Data" with x-axis for samples and y-axis for amplitude.
#
# Second Subplot: Plots the `synthetic_data` array. Labels the plot as "Synthetic Seismic Data" with the same axis labels.
#
# Third Subplot: Plots the `combined_data`/ Labels the plot as "Combined Seismic Data", maintaining the labels.
#
# 3. **Layout Adjustments**
# The function uses `plt.tight_layout()` to ensure there is no overlapping of subplot titles or axes.
#
# 4. **Saving the Plot**
# The plot is saved as `seismic_data_comparison.png` in the specified `base_dir` directory using the `os.path.join` method.
#
# 5. **Closing the Plot**
# `plt.close()` ensures the figure is properly closed, freeing up memory resources and avoiding display in the environment.

# %%
def plot_seismic_data(real_data, synthetic_data, combined_data, base_dir):
  plt.figure(figsize=(15, 10))

  plt.subplot(3,1,1)
  plt.plot(real_data)
  plt.title('Real Seismic Data')
  plt.xlabel('Samples')
  plt.ylabel('Amplitude')

  plt.subplot(3,1,2)
  plt.plot(synthetic_data)
  plt.title('Synthetic Seismic Data')
  plt.xlabel('Sample')
  plt.ylabel('Amplitude')

  plt.subplot(3,1,3)
  plt.plot(combined_data)
  plt.title('Combined Seismic Data')
  plt.xlabel('Sample')
  plt.ylabel('Amplitude')

  plt.tight_layout()
  plt.savefig(os.path.join(base_dir, "seismic_data_comparison.png"))
  plt.close()

# %% [markdown]
# #The Main Function
# The `main` function orchestrates the complete workflow for processing seismic data, generating synthetic data, combining datasets, and training a model detect seismic events. It integrates data preparation, visualization and machinelearning in a sequential and modular manner.
#
# ##Steps and functionality
# 1. **Configuration Setup**
# Defines a configuration dictionary `config` with parameters for:
#
#   `window_size`: Size of the data window for training.
#
#   `step`: Step size for sliding window operations.
#
#   `sample_rate`: Default sampling rate (Hz).
#
#   `num_samples`: Number of samples in fallback synthetic data.
#
# 2. **Output Directory Creation**
# Calls `create_output_directory` to create a directory for saving all outputs, including plots and model files.
#
# 3. **Fetching real earthquake data**
# Defines the earthquake's origin time using `UTCDateTime` and fetches data using `fetch_iris_data` with:
#
#   Seismic network, station and channel information.
#
#   `origin_time` for temporal alignment.
#
#   Duration of 120 seconds.
#
# If the data fetch is successful:
#
#    Processes the data stream using `process_stream` to filter the signal and compute the charcteristic function (`real_cft`).
#
#   Extracts raw data and its sampling rate.
#
# If no data is fetched:
#
#   Initializes fallback data as a zero-filled array with length `num_samples` and defualt `sample_rate`.
#
#   Sets `real_cft` to `None`.
#
# 4. **Synthetic Data Generation**
# Calls `generate_synthetic_data` to create synthetic seismic data with parameters:
#
#   Length equal to the rel data.
#
#   Sampling rate.
#
#   Event duration (2 seconds) and noise level(0.1)
#
# Outputs include:
#
#   `synthetic_data`: Generated data.
#
#   `synthetic_events`: List of synthetic event times.
#
#   `synthetic_event_location`: Location of synthetic events in the data.
#
# 5. **Combining Datasets**:
# Adds `real_data` and `synthetic_data` element wise to create `combined_data`, simulating real-world scenarios where noise and real seismic signals overlap.
#
# 6. **Creating Windows and labels**
# Uses `create_enhanced_windows` to split `combined_data` into sliding widows with:
#
#   Defines `window_size` and `step` from the configuration
#
#   Event locations (`synthetic_event_location`) for labelling.
#
#   The real signal's characteristic function (`real_cft`) to refine labelling.
#
# 7. **Model Traing and Evaluation**
# Calls `train_evaluate_model` to train the model using:
#
#   Features (`X`) and labels (`y`) from the windowed data.
#
#   Outputs the trained model and cross-validation scores.
#
# 8. **Visualization**
# Generates a plot comparing `real_data`, `synthetic_data` and `combined_data` using `plot_seismic_data` saving it in the `base_dir`.

# %%
def main():
    # Configuration
    config = {
        'window_size': 250,
        'step': 25,
        'sample_rate': 100,
        'num_samples': 25000
    }

    # Create output directory
    base_dir = create_output_directory()

    # Fetch real earthquake data
    origin_time = UTCDateTime("2015-08-11T16:22:15.200000")
    real_stream = fetch_iris_data(
        network='YS', station='BAOP', location='',
        channel='BHZ', origin_time=origin_time, duration=120
    )

    # Process real and synthetic data
    if real_stream is not None:
        filtered_real_stream, real_cft = process_stream(real_stream)
        real_data = filtered_real_stream[0].data
        sample_rate = real_stream[0].stats.sampling_rate
    else:
        # Fallback to default values if no real data
        real_data = np.zeros(config['num_samples'])
        sample_rate = config['sample_rate']
        real_cft = None

    # Generate synthetic data
    synthetic_data, synthetic_events, synthetic_event_locations = generate_synthetic_data(
        len(real_data),
        sample_rate,
        event_duration=2,
        noise_level=0.1
    )

    # Combine datasets
    combined_data = real_data + synthetic_data

    # Create windows and labels
    X, y = create_enhanced_windows(
        combined_data,
        config['window_size'],
        config['step'],
        synthetic_event_locations,
        real_cft
    )

    # Train and evaluate model
    trained_model, cv_scores = train_and_evaluate_model(X, y, base_dir)
    plot_seismic_data(real_data, synthetic_data, combined_data, base_dir)

    print("\nModel training and evaluation complete. Check the output directory for visualizations.")

# %%
if __name__=="__main__":
  main()
# Out:
# === Fold 1===
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - accuracy: 0.6317 - loss: 2.9141 - precision: 0.4740 - recall: 0.2901 - val_accuracy: 0.2500 - val_loss: 1.9969 - val_precision: 0.2222 - val_recall: 0.5000 - learning_rate: 3.0000e-04
# Epoch 2/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.5695 - loss: 2.9611 - precision: 0.2398 - recall: 0.1695 - val_accuracy: 0.3333 - val_loss: 1.9912 - val_precision: 0.3000 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 3/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.5977 - loss: 2.6112 - precision: 0.4120 - recall: 0.3452 - val_accuracy: 0.3750 - val_loss: 1.9873 - val_precision: 0.3158 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.6023 - loss: 2.6705 - precision: 0.4231 - recall: 0.4869 - val_accuracy: 0.4167 - val_loss: 1.9868 - val_precision: 0.3333 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.6424 - loss: 2.5433 - precision: 0.4811 - recall: 0.5298 - val_accuracy: 0.4167 - val_loss: 1.9859 - val_precision: 0.3333 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.6441 - loss: 2.4476 - precision: 0.5092 - recall: 0.5841 - val_accuracy: 0.4583 - val_loss: 1.9753 - val_precision: 0.3529 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - accuracy: 0.6149 - loss: 2.4170 - precision: 0.4796 - recall: 0.6222 - val_accuracy: 0.5417 - val_loss: 1.9709 - val_precision: 0.4000 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.6861 - loss: 2.3591 - precision: 0.5075 - recall: 0.6143 - val_accuracy: 0.5833 - val_loss: 1.9657 - val_precision: 0.4286 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.6782 - loss: 2.2908 - precision: 0.5348 - recall: 0.6767 - val_accuracy: 0.5833 - val_loss: 1.9636 - val_precision: 0.4286 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.6689 - loss: 2.3639 - precision: 0.5440 - recall: 0.6991 - val_accuracy: 0.6250 - val_loss: 1.9681 - val_precision: 0.4615 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 11/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.6806 - loss: 2.2137 - precision: 0.5264 - recall: 0.7927 - val_accuracy: 0.6667 - val_loss: 1.9675 - val_precision: 0.5000 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 12/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 0.6240 - loss: 2.3804 - precision: 0.4491 - recall: 0.6487 - val_accuracy: 0.6667 - val_loss: 1.9680 - val_precision: 0.5000 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 13/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.6282 - loss: 2.2273 - precision: 0.4381 - recall: 0.6850 - val_accuracy: 0.6667 - val_loss: 1.9708 - val_precision: 0.5000 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 14/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.7030 - loss: 2.1712 - precision: 0.5434 - recall: 0.8022 - val_accuracy: 0.6250 - val_loss: 1.9773 - val_precision: 0.4615 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 15/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - accuracy: 0.6432 - loss: 2.3888 - precision: 0.5035 - recall: 0.7176 - val_accuracy: 0.6250 - val_loss: 1.9778 - val_precision: 0.4615 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 16/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.5689 - loss: 2.3232 - precision: 0.4277 - recall: 0.6799 - val_accuracy: 0.6250 - val_loss: 1.9882 - val_precision: 0.4615 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.6734 - loss: 2.2461 - precision: 0.5478 - recall: 0.7641 - val_accuracy: 0.6250 - val_loss: 2.0053 - val_precision: 0.4615 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.6616 - loss: 2.2202 - precision: 0.5309 - recall: 0.7876 - val_accuracy: 0.6250 - val_loss: 2.0137 - val_precision: 0.4615 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 0.6255 - loss: 2.3656 - precision: 0.4749 - recall: 0.7295 - val_accuracy: 0.5833 - val_loss: 2.0082 - val_precision: 0.4286 - val_recall: 0.7500 - learning_rate: 3.0000e-04
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.6822 - loss: 2.2070 - precision: 0.5060 - recall: 0.8144 - val_accuracy: 0.5833 - val_loss: 2.0054 - val_precision: 0.4286 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 0.7022 - loss: 2.2107 - precision: 0.5697 - recall: 0.8346 - val_accuracy: 0.5417 - val_loss: 2.0090 - val_precision: 0.4000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 22/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.5995 - loss: 2.3935 - precision: 0.4729 - recall: 0.6909 - val_accuracy: 0.5417 - val_loss: 2.0221 - val_precision: 0.4000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 23/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.6949 - loss: 2.1020 - precision: 0.5404 - recall: 0.8762 - val_accuracy: 0.5417 - val_loss: 2.0358 - val_precision: 0.4000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 24/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.6569 - loss: 2.1517 - precision: 0.4949 - recall: 0.8036 - val_accuracy: 0.5417 - val_loss: 2.0401 - val_precision: 0.4000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 25/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 0.6531 - loss: 2.2012 - precision: 0.5024 - recall: 0.8103 - val_accuracy: 0.5417 - val_loss: 2.0530 - val_precision: 0.4000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 26/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 0.6654 - loss: 2.1374 - precision: 0.5022 - recall: 0.8213 - val_accuracy: 0.5833 - val_loss: 2.0542 - val_precision: 0.4286 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 27/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.7012 - loss: 2.1363 - precision: 0.5509 - recall: 0.8009 - val_accuracy: 0.6667 - val_loss: 2.0623 - val_precision: 0.5000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 28/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step - accuracy: 0.6870 - loss: 2.1459 - precision: 0.5624 - recall: 0.7771 - val_accuracy: 0.6667 - val_loss: 2.0715 - val_precision: 0.5000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# Epoch 29/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6955 - loss: 2.0330 - precision: 0.5474 - recall: 0.8351 - val_accuracy: 0.6667 - val_loss: 2.0756 - val_precision: 0.5000 - val_recall: 0.7500 - learning_rate: 9.0000e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.50      0.62        16
#            1       0.43      0.75      0.55         8
#
#     accuracy                           0.58        24
#    macro avg       0.61      0.62      0.58        24
# weighted avg       0.68      0.58      0.59        24
#
#
# === Fold 2===
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 376ms/step - accuracy: 0.4267 - loss: 2.7159 - precision_1: 0.3066 - recall_1: 0.5224 - val_accuracy: 0.5652 - val_loss: 1.9809 - val_precision_1: 0.4167 - val_recall_1: 0.6250 - learning_rate: 3.0000e-04
# Epoch 2/150
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_recall available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.5443 - loss: 2.5723 - precision_1: 0.3780 - recall_1: 0.6179 - val_accuracy: 0.3478 - val_loss: 1.9861 - val_precision_1: 0.3333 - val_recall_1: 0.8750 - learning_rate: 3.0000e-04
# Epoch 3/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 284ms/step - accuracy: 0.6018 - loss: 2.3929 - precision_1: 0.4495 - recall_1: 0.7665 - val_accuracy: 0.3478 - val_loss: 1.9941 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step - accuracy: 0.6127 - loss: 2.3013 - precision_1: 0.4580 - recall_1: 0.8021 - val_accuracy: 0.3478 - val_loss: 2.0049 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.6274 - loss: 2.2457 - precision_1: 0.4768 - recall_1: 0.8438 - val_accuracy: 0.3478 - val_loss: 2.0202 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.6238 - loss: 2.2117 - precision_1: 0.4467 - recall_1: 0.7194 - val_accuracy: 0.3478 - val_loss: 2.0402 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step - accuracy: 0.6491 - loss: 2.2097 - precision_1: 0.5145 - recall_1: 0.7720 - val_accuracy: 0.3478 - val_loss: 2.0505 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.6065 - loss: 2.4169 - precision_1: 0.4960 - recall_1: 0.7471 - val_accuracy: 0.3478 - val_loss: 2.0602 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.6907 - loss: 2.1971 - precision_1: 0.5559 - recall_1: 0.8069 - val_accuracy: 0.3478 - val_loss: 2.0774 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - accuracy: 0.5989 - loss: 2.3079 - precision_1: 0.4453 - recall_1: 0.7769 - val_accuracy: 0.3478 - val_loss: 2.0921 - val_precision_1: 0.3478 - val_recall_1: 1.0000 - learning_rate: 3.0000e-04
# Epoch 11/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.5978 - loss: 2.2994 - precision_1: 0.4003 - recall_1: 0.8177 - val_accuracy: 0.3043 - val_loss: 2.1065 - val_precision_1: 0.3182 - val_recall_1: 0.8750 - learning_rate: 3.0000e-04
# Epoch 12/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.6710 - loss: 2.1351 - precision_1: 0.5018 - recall_1: 0.8709 - val_accuracy: 0.3043 - val_loss: 2.1192 - val_precision_1: 0.3182 - val_recall_1: 0.8750 - learning_rate: 9.0000e-05
# Epoch 13/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.6561 - loss: 2.3014 - precision_1: 0.5186 - recall_1: 0.7821 - val_accuracy: 0.3043 - val_loss: 2.1320 - val_precision_1: 0.3182 - val_recall_1: 0.8750 - learning_rate: 9.0000e-05
# Epoch 14/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.6528 - loss: 2.2905 - precision_1: 0.5136 - recall_1: 0.7656 - val_accuracy: 0.3043 - val_loss: 2.1441 - val_precision_1: 0.3182 - val_recall_1: 0.8750 - learning_rate: 9.0000e-05
# Epoch 15/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.5928 - loss: 2.3714 - precision_1: 0.4563 - recall_1: 0.7207 - val_accuracy: 0.3043 - val_loss: 2.1537 - val_precision_1: 0.3182 - val_recall_1: 0.8750 - learning_rate: 9.0000e-05
# Epoch 16/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - accuracy: 0.6446 - loss: 2.2056 - precision_1: 0.4890 - recall_1: 0.7757 - val_accuracy: 0.2609 - val_loss: 2.1663 - val_precision_1: 0.2857 - val_recall_1: 0.7500 - learning_rate: 9.0000e-05
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - accuracy: 0.6588 - loss: 2.0819 - precision_1: 0.4852 - recall_1: 0.8445 - val_accuracy: 0.2609 - val_loss: 2.1837 - val_precision_1: 0.2857 - val_recall_1: 0.7500 - learning_rate: 9.0000e-05
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.6568 - loss: 2.1120 - precision_1: 0.5063 - recall_1: 0.8332 - val_accuracy: 0.3043 - val_loss: 2.1992 - val_precision_1: 0.3000 - val_recall_1: 0.7500 - learning_rate: 9.0000e-05
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.6289 - loss: 2.1699 - precision_1: 0.4252 - recall_1: 0.9038 - val_accuracy: 0.3478 - val_loss: 2.2106 - val_precision_1: 0.3158 - val_recall_1: 0.7500 - learning_rate: 9.0000e-05
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.6631 - loss: 2.1520 - precision_1: 0.5080 - recall_1: 0.8472 - val_accuracy: 0.3478 - val_loss: 2.2273 - val_precision_1: 0.3158 - val_recall_1: 0.7500 - learning_rate: 9.0000e-05
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.6381 - loss: 2.3430 - precision_1: 0.4729 - recall_1: 0.7931 - val_accuracy: 0.3478 - val_loss: 2.2367 - val_precision_1: 0.3158 - val_recall_1: 0.7500 - learning_rate: 9.0000e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.53      0.62        15
#            1       0.42      0.62      0.50         8
#
#     accuracy                           0.57        23
#    macro avg       0.57      0.58      0.56        23
# weighted avg       0.62      0.57      0.58        23
#
#
# === Fold 3===
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - accuracy: 0.4393 - loss: 2.6455 - precision_2: 0.3367 - recall_2: 0.6238 - val_accuracy: 0.4783 - val_loss: 1.9705 - val_precision_2: 0.3333 - val_recall_2: 0.5000 - learning_rate: 3.0000e-04
# Epoch 2/150
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_recall available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.5245 - loss: 2.4758 - precision_2: 0.4017 - recall_2: 0.6710 - val_accuracy: 0.5217 - val_loss: 1.9657 - val_precision_2: 0.3636 - val_recall_2: 0.5000 - learning_rate: 3.0000e-04
# Epoch 3/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.5811 - loss: 2.3762 - precision_2: 0.4498 - recall_2: 0.7229 - val_accuracy: 0.5217 - val_loss: 1.9623 - val_precision_2: 0.3636 - val_recall_2: 0.5000 - learning_rate: 3.0000e-04
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.5430 - loss: 2.3894 - precision_2: 0.4056 - recall_2: 0.7739 - val_accuracy: 0.3913 - val_loss: 1.9623 - val_precision_2: 0.3125 - val_recall_2: 0.6250 - learning_rate: 3.0000e-04
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.5792 - loss: 2.3316 - precision_2: 0.4227 - recall_2: 0.7620 - val_accuracy: 0.4783 - val_loss: 1.9634 - val_precision_2: 0.3889 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.6356 - loss: 2.3109 - precision_2: 0.5062 - recall_2: 0.8061 - val_accuracy: 0.4783 - val_loss: 1.9595 - val_precision_2: 0.3889 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.6023 - loss: 2.3308 - precision_2: 0.4664 - recall_2: 0.8271 - val_accuracy: 0.4783 - val_loss: 1.9567 - val_precision_2: 0.3750 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.5687 - loss: 2.5168 - precision_2: 0.4283 - recall_2: 0.6927 - val_accuracy: 0.5217 - val_loss: 1.9572 - val_precision_2: 0.4000 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6197 - loss: 2.3080 - precision_2: 0.4821 - recall_2: 0.8024 - val_accuracy: 0.5652 - val_loss: 1.9518 - val_precision_2: 0.4286 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.5889 - loss: 2.4536 - precision_2: 0.4499 - recall_2: 0.7340 - val_accuracy: 0.5652 - val_loss: 1.9474 - val_precision_2: 0.4375 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 11/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - accuracy: 0.6464 - loss: 2.3114 - precision_2: 0.5137 - recall_2: 0.8165 - val_accuracy: 0.5652 - val_loss: 1.9488 - val_precision_2: 0.4375 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 12/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - accuracy: 0.6394 - loss: 2.2309 - precision_2: 0.4818 - recall_2: 0.9257 - val_accuracy: 0.5652 - val_loss: 1.9515 - val_precision_2: 0.4375 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 13/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.6131 - loss: 2.2426 - precision_2: 0.4536 - recall_2: 0.8531 - val_accuracy: 0.5217 - val_loss: 1.9511 - val_precision_2: 0.4211 - val_recall_2: 1.0000 - learning_rate: 3.0000e-04
# Epoch 14/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.5952 - loss: 2.2707 - precision_2: 0.4661 - recall_2: 0.8402 - val_accuracy: 0.5652 - val_loss: 1.9520 - val_precision_2: 0.4444 - val_recall_2: 1.0000 - learning_rate: 3.0000e-04
# Epoch 15/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.6386 - loss: 2.2339 - precision_2: 0.4927 - recall_2: 0.8687 - val_accuracy: 0.5217 - val_loss: 1.9474 - val_precision_2: 0.4211 - val_recall_2: 1.0000 - learning_rate: 3.0000e-04
# Epoch 16/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.6415 - loss: 2.3218 - precision_2: 0.5016 - recall_2: 0.7611 - val_accuracy: 0.4348 - val_loss: 1.9455 - val_precision_2: 0.3529 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.6151 - loss: 2.1541 - precision_2: 0.4266 - recall_2: 0.8551 - val_accuracy: 0.5217 - val_loss: 1.9548 - val_precision_2: 0.4118 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.6530 - loss: 2.1162 - precision_2: 0.5215 - recall_2: 0.8592 - val_accuracy: 0.6087 - val_loss: 1.9406 - val_precision_2: 0.4667 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - accuracy: 0.6597 - loss: 2.1852 - precision_2: 0.4949 - recall_2: 0.7880 - val_accuracy: 0.6522 - val_loss: 1.9059 - val_precision_2: 0.5000 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.7155 - loss: 2.1025 - precision_2: 0.5739 - recall_2: 0.8780 - val_accuracy: 0.6957 - val_loss: 1.8872 - val_precision_2: 0.5455 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.6495 - loss: 2.1225 - precision_2: 0.4832 - recall_2: 0.8476 - val_accuracy: 0.6957 - val_loss: 1.8688 - val_precision_2: 0.5556 - val_recall_2: 0.6250 - learning_rate: 3.0000e-04
# Epoch 22/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.6457 - loss: 2.2613 - precision_2: 0.4941 - recall_2: 0.7880 - val_accuracy: 0.6957 - val_loss: 1.8477 - val_precision_2: 0.5556 - val_recall_2: 0.6250 - learning_rate: 3.0000e-04
# Epoch 23/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.6600 - loss: 2.1333 - precision_2: 0.4993 - recall_2: 0.7714 - val_accuracy: 0.7391 - val_loss: 1.8459 - val_precision_2: 0.6000 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 24/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.7237 - loss: 2.0363 - precision_2: 0.5681 - recall_2: 0.9160 - val_accuracy: 0.7391 - val_loss: 1.8480 - val_precision_2: 0.5833 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 25/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - accuracy: 0.6200 - loss: 2.2550 - precision_2: 0.4307 - recall_2: 0.7695 - val_accuracy: 0.6957 - val_loss: 1.8477 - val_precision_2: 0.5455 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 26/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.6033 - loss: 2.1825 - precision_2: 0.4296 - recall_2: 0.7860 - val_accuracy: 0.7391 - val_loss: 1.8424 - val_precision_2: 0.6000 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 27/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.6417 - loss: 2.1226 - precision_2: 0.5015 - recall_2: 0.8281 - val_accuracy: 0.7391 - val_loss: 1.8319 - val_precision_2: 0.5833 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 28/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.6586 - loss: 2.0949 - precision_2: 0.5046 - recall_2: 0.8038 - val_accuracy: 0.7391 - val_loss: 1.8113 - val_precision_2: 0.5833 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 29/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6713 - loss: 2.1157 - precision_2: 0.5231 - recall_2: 0.8144 - val_accuracy: 0.7391 - val_loss: 1.8262 - val_precision_2: 0.5833 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 30/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.7030 - loss: 2.0203 - precision_2: 0.5310 - recall_2: 0.9133 - val_accuracy: 0.6522 - val_loss: 1.8314 - val_precision_2: 0.5000 - val_recall_2: 1.0000 - learning_rate: 3.0000e-04
# Epoch 31/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.6511 - loss: 2.1390 - precision_2: 0.5328 - recall_2: 0.8112 - val_accuracy: 0.6957 - val_loss: 1.7992 - val_precision_2: 0.5333 - val_recall_2: 1.0000 - learning_rate: 3.0000e-04
# Epoch 32/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.6760 - loss: 2.0457 - precision_2: 0.5203 - recall_2: 0.8918 - val_accuracy: 0.6957 - val_loss: 1.7974 - val_precision_2: 0.5333 - val_recall_2: 1.0000 - learning_rate: 3.0000e-04
# Epoch 33/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 0.7112 - loss: 2.0630 - precision_2: 0.5651 - recall_2: 0.9131 - val_accuracy: 0.7391 - val_loss: 1.7604 - val_precision_2: 0.5833 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 34/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.7140 - loss: 1.9539 - precision_2: 0.5768 - recall_2: 0.8955 - val_accuracy: 0.7391 - val_loss: 1.7336 - val_precision_2: 0.5833 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 35/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.7396 - loss: 1.9155 - precision_2: 0.5708 - recall_2: 0.9199 - val_accuracy: 0.7391 - val_loss: 1.7341 - val_precision_2: 0.5833 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 36/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.7486 - loss: 1.9734 - precision_2: 0.6299 - recall_2: 0.8626 - val_accuracy: 0.7391 - val_loss: 1.7789 - val_precision_2: 0.6000 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 37/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - accuracy: 0.7066 - loss: 2.0574 - precision_2: 0.5826 - recall_2: 0.8301 - val_accuracy: 0.7391 - val_loss: 1.7494 - val_precision_2: 0.6000 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 38/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.6893 - loss: 2.0737 - precision_2: 0.4758 - recall_2: 0.8954 - val_accuracy: 0.7826 - val_loss: 1.7200 - val_precision_2: 0.6364 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 39/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.7391 - loss: 1.9390 - precision_2: 0.5801 - recall_2: 0.8878 - val_accuracy: 0.7391 - val_loss: 1.7361 - val_precision_2: 0.6000 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 40/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.7747 - loss: 1.9274 - precision_2: 0.6433 - recall_2: 0.9201 - val_accuracy: 0.7826 - val_loss: 1.7476 - val_precision_2: 0.6364 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 41/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 282ms/step - accuracy: 0.7616 - loss: 1.9418 - precision_2: 0.6153 - recall_2: 0.8792 - val_accuracy: 0.7826 - val_loss: 1.7219 - val_precision_2: 0.6364 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 42/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.7332 - loss: 2.0213 - precision_2: 0.5762 - recall_2: 0.8786 - val_accuracy: 0.6957 - val_loss: 1.7379 - val_precision_2: 0.5455 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 43/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.7536 - loss: 1.9216 - precision_2: 0.6147 - recall_2: 0.8792 - val_accuracy: 0.6087 - val_loss: 1.8357 - val_precision_2: 0.4667 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 44/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.7414 - loss: 1.8852 - precision_2: 0.5937 - recall_2: 0.9134 - val_accuracy: 0.6087 - val_loss: 1.8528 - val_precision_2: 0.4667 - val_recall_2: 0.8750 - learning_rate: 3.0000e-04
# Epoch 45/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.7378 - loss: 1.9852 - precision_2: 0.5944 - recall_2: 0.8721 - val_accuracy: 0.5652 - val_loss: 1.8285 - val_precision_2: 0.4286 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 46/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.7316 - loss: 1.9357 - precision_2: 0.5483 - recall_2: 0.9203 - val_accuracy: 0.6087 - val_loss: 1.7770 - val_precision_2: 0.4615 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 47/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.7756 - loss: 1.8022 - precision_2: 0.6211 - recall_2: 0.9496 - val_accuracy: 0.6957 - val_loss: 1.7247 - val_precision_2: 0.5556 - val_recall_2: 0.6250 - learning_rate: 3.0000e-04
# Epoch 48/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - accuracy: 0.7359 - loss: 1.8556 - precision_2: 0.5617 - recall_2: 0.8912 - val_accuracy: 0.6087 - val_loss: 1.7699 - val_precision_2: 0.4615 - val_recall_2: 0.7500 - learning_rate: 3.0000e-04
# Epoch 49/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.7773 - loss: 1.9163 - precision_2: 0.6486 - recall_2: 0.9185 - val_accuracy: 0.6087 - val_loss: 1.7968 - val_precision_2: 0.4615 - val_recall_2: 0.7500 - learning_rate: 9.0000e-05
# Epoch 50/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.7746 - loss: 1.8243 - precision_2: 0.6098 - recall_2: 0.9682 - val_accuracy: 0.6522 - val_loss: 1.7853 - val_precision_2: 0.5000 - val_recall_2: 0.8750 - learning_rate: 9.0000e-05
# Epoch 51/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.7880 - loss: 1.8280 - precision_2: 0.6378 - recall_2: 0.9574 - val_accuracy: 0.6522 - val_loss: 1.7687 - val_precision_2: 0.5000 - val_recall_2: 0.8750 - learning_rate: 9.0000e-05
# Epoch 52/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.7021 - loss: 1.9235 - precision_2: 0.5217 - recall_2: 0.9170 - val_accuracy: 0.6522 - val_loss: 1.7661 - val_precision_2: 0.5000 - val_recall_2: 0.8750 - learning_rate: 9.0000e-05
# Epoch 53/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.7756 - loss: 1.8331 - precision_2: 0.6101 - recall_2: 0.9084 - val_accuracy: 0.6087 - val_loss: 1.7699 - val_precision_2: 0.4667 - val_recall_2: 0.8750 - learning_rate: 9.0000e-05
# Epoch 54/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.7561 - loss: 1.8755 - precision_2: 0.5763 - recall_2: 0.9106 - val_accuracy: 0.6087 - val_loss: 1.7896 - val_precision_2: 0.4667 - val_recall_2: 0.8750 - learning_rate: 9.0000e-05
# Epoch 55/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.7195 - loss: 1.9365 - precision_2: 0.6013 - recall_2: 0.8588 - val_accuracy: 0.6957 - val_loss: 1.7649 - val_precision_2: 0.5385 - val_recall_2: 0.8750 - learning_rate: 9.0000e-05
# Epoch 56/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - accuracy: 0.7246 - loss: 1.8738 - precision_2: 0.5718 - recall_2: 0.8963 - val_accuracy: 0.6957 - val_loss: 1.7566 - val_precision_2: 0.5385 - val_recall_2: 0.8750 - learning_rate: 9.0000e-05
# Epoch 57/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.7762 - loss: 1.7780 - precision_2: 0.5969 - recall_2: 0.9187 - val_accuracy: 0.6087 - val_loss: 1.7844 - val_precision_2: 0.4615 - val_recall_2: 0.7500 - learning_rate: 9.0000e-05
# Epoch 58/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.7650 - loss: 1.8226 - precision_2: 0.5967 - recall_2: 0.9342 - val_accuracy: 0.6522 - val_loss: 1.7504 - val_precision_2: 0.5000 - val_recall_2: 0.6250 - learning_rate: 9.0000e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81        15
#            1       0.64      0.88      0.74         8
#
#     accuracy                           0.78        23
#    macro avg       0.78      0.80      0.78        23
# weighted avg       0.82      0.78      0.79        23
#
#
# === Fold 4===
# Epoch 1/150
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - accuracy: 0.4312 - loss: 2.7213 - precision_3: 0.4073 - recall_3: 0.9522 - val_accuracy: 0.3478 - val_loss: 2.0772 - val_precision_3: 0.3478 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 2/150
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/model_checkpoint.py:302: UserWarning: Can save best model only with val_recall available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.3435 - loss: 2.8162 - precision_3: 0.3187 - recall_3: 0.9612 - val_accuracy: 0.3478 - val_loss: 2.0795 - val_precision_3: 0.3478 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 3/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.4761 - loss: 2.5760 - precision_3: 0.4077 - recall_3: 1.0000 - val_accuracy: 0.3478 - val_loss: 2.0728 - val_precision_3: 0.3478 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.3769 - loss: 2.7358 - precision_3: 0.3393 - recall_3: 0.9610 - val_accuracy: 0.3478 - val_loss: 2.0602 - val_precision_3: 0.3478 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.4583 - loss: 2.4977 - precision_3: 0.3695 - recall_3: 0.9484 - val_accuracy: 0.3478 - val_loss: 2.0564 - val_precision_3: 0.3478 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - accuracy: 0.3779 - loss: 2.6117 - precision_3: 0.3167 - recall_3: 0.7819 - val_accuracy: 0.3478 - val_loss: 2.0429 - val_precision_3: 0.3478 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.4877 - loss: 2.3789 - precision_3: 0.3973 - recall_3: 0.9845 - val_accuracy: 0.3478 - val_loss: 2.0291 - val_precision_3: 0.3478 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - accuracy: 0.4827 - loss: 2.4049 - precision_3: 0.4051 - recall_3: 0.9543 - val_accuracy: 0.3913 - val_loss: 1.9934 - val_precision_3: 0.3636 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.4786 - loss: 2.4539 - precision_3: 0.3902 - recall_3: 0.8023 - val_accuracy: 0.5217 - val_loss: 1.9509 - val_precision_3: 0.4211 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.5403 - loss: 2.3132 - precision_3: 0.4321 - recall_3: 0.8987 - val_accuracy: 0.6957 - val_loss: 1.9248 - val_precision_3: 0.5385 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 11/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - accuracy: 0.5817 - loss: 2.3779 - precision_3: 0.4752 - recall_3: 0.8889 - val_accuracy: 0.6957 - val_loss: 1.9185 - val_precision_3: 0.5385 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 12/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.6204 - loss: 2.2153 - precision_3: 0.4893 - recall_3: 0.9047 - val_accuracy: 0.6522 - val_loss: 1.9119 - val_precision_3: 0.5000 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 13/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 290ms/step - accuracy: 0.5861 - loss: 2.2711 - precision_3: 0.4432 - recall_3: 0.8493 - val_accuracy: 0.6522 - val_loss: 1.9031 - val_precision_3: 0.5000 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 14/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 0.5552 - loss: 2.3635 - precision_3: 0.4387 - recall_3: 0.7667 - val_accuracy: 0.6522 - val_loss: 1.8956 - val_precision_3: 0.5000 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 15/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.5995 - loss: 2.2607 - precision_3: 0.4647 - recall_3: 0.8440 - val_accuracy: 0.6957 - val_loss: 1.8922 - val_precision_3: 0.5556 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 16/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.6036 - loss: 2.1957 - precision_3: 0.4539 - recall_3: 0.8418 - val_accuracy: 0.6522 - val_loss: 1.8872 - val_precision_3: 0.5000 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.6056 - loss: 2.2414 - precision_3: 0.4709 - recall_3: 0.7892 - val_accuracy: 0.6957 - val_loss: 1.8898 - val_precision_3: 0.5556 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.6101 - loss: 2.2460 - precision_3: 0.4768 - recall_3: 0.9017 - val_accuracy: 0.6522 - val_loss: 1.8845 - val_precision_3: 0.5000 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.6140 - loss: 2.3161 - precision_3: 0.4800 - recall_3: 0.8721 - val_accuracy: 0.6957 - val_loss: 1.8718 - val_precision_3: 0.5556 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - accuracy: 0.6326 - loss: 2.2227 - precision_3: 0.5033 - recall_3: 0.8240 - val_accuracy: 0.6522 - val_loss: 1.8623 - val_precision_3: 0.5000 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.5864 - loss: 2.3056 - precision_3: 0.4227 - recall_3: 0.7516 - val_accuracy: 0.6522 - val_loss: 1.8446 - val_precision_3: 0.5000 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 22/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6557 - loss: 2.1706 - precision_3: 0.5503 - recall_3: 0.8160 - val_accuracy: 0.6957 - val_loss: 1.8206 - val_precision_3: 0.5714 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 23/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.6002 - loss: 2.2541 - precision_3: 0.4162 - recall_3: 0.8129 - val_accuracy: 0.7391 - val_loss: 1.7934 - val_precision_3: 0.6667 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 24/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6164 - loss: 2.2411 - precision_3: 0.4321 - recall_3: 0.7437 - val_accuracy: 0.7826 - val_loss: 1.7768 - val_precision_3: 0.7143 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 25/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.7267 - loss: 2.1729 - precision_3: 0.6010 - recall_3: 0.8645 - val_accuracy: 0.7391 - val_loss: 1.7676 - val_precision_3: 0.6667 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 26/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6500 - loss: 2.1518 - precision_3: 0.5003 - recall_3: 0.8381 - val_accuracy: 0.7391 - val_loss: 1.7704 - val_precision_3: 0.6667 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 27/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6844 - loss: 2.1235 - precision_3: 0.5434 - recall_3: 0.8579 - val_accuracy: 0.7391 - val_loss: 1.7652 - val_precision_3: 0.6667 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 28/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.6557 - loss: 2.1370 - precision_3: 0.4713 - recall_3: 0.8500 - val_accuracy: 0.6957 - val_loss: 1.7563 - val_precision_3: 0.5714 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 29/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6414 - loss: 2.1517 - precision_3: 0.4902 - recall_3: 0.7783 - val_accuracy: 0.6957 - val_loss: 1.7317 - val_precision_3: 0.5714 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 30/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.6918 - loss: 2.0980 - precision_3: 0.4959 - recall_3: 0.8848 - val_accuracy: 0.7391 - val_loss: 1.7262 - val_precision_3: 0.6667 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 31/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.6858 - loss: 2.1160 - precision_3: 0.5604 - recall_3: 0.8233 - val_accuracy: 0.6957 - val_loss: 1.7401 - val_precision_3: 0.5714 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 32/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.6859 - loss: 2.0730 - precision_3: 0.5223 - recall_3: 0.9116 - val_accuracy: 0.6957 - val_loss: 1.7445 - val_precision_3: 0.5714 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 33/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.6714 - loss: 2.1388 - precision_3: 0.4906 - recall_3: 0.8864 - val_accuracy: 0.6957 - val_loss: 1.7150 - val_precision_3: 0.5714 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 34/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.6566 - loss: 2.0853 - precision_3: 0.4938 - recall_3: 0.8392 - val_accuracy: 0.7391 - val_loss: 1.6911 - val_precision_3: 0.6667 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 35/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - accuracy: 0.6878 - loss: 2.0477 - precision_3: 0.5141 - recall_3: 0.8517 - val_accuracy: 0.7826 - val_loss: 1.6830 - val_precision_3: 0.7143 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 36/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.6976 - loss: 2.0348 - precision_3: 0.5362 - recall_3: 0.8919 - val_accuracy: 0.7826 - val_loss: 1.6926 - val_precision_3: 0.6667 - val_recall_3: 0.7500 - learning_rate: 3.0000e-04
# Epoch 37/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6588 - loss: 2.0762 - precision_3: 0.5032 - recall_3: 0.8181 - val_accuracy: 0.7391 - val_loss: 1.7065 - val_precision_3: 0.6667 - val_recall_3: 0.5000 - learning_rate: 3.0000e-04
# Epoch 38/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - accuracy: 0.6803 - loss: 2.0021 - precision_3: 0.5193 - recall_3: 0.8113 - val_accuracy: 0.7391 - val_loss: 1.6926 - val_precision_3: 0.6250 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 39/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.7054 - loss: 2.0389 - precision_3: 0.5540 - recall_3: 0.8031 - val_accuracy: 0.8696 - val_loss: 1.6859 - val_precision_3: 0.7778 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 40/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 223ms/step - accuracy: 0.7183 - loss: 1.9904 - precision_3: 0.5519 - recall_3: 0.8601 - val_accuracy: 0.8261 - val_loss: 1.6753 - val_precision_3: 0.7500 - val_recall_3: 0.7500 - learning_rate: 3.0000e-04
# Epoch 41/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.7014 - loss: 2.0303 - precision_3: 0.5228 - recall_3: 0.8271 - val_accuracy: 0.8696 - val_loss: 1.6305 - val_precision_3: 0.7778 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 42/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - accuracy: 0.7139 - loss: 2.0053 - precision_3: 0.5554 - recall_3: 0.8709 - val_accuracy: 0.9130 - val_loss: 1.5995 - val_precision_3: 0.8000 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 43/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.7432 - loss: 1.8678 - precision_3: 0.5947 - recall_3: 0.8944 - val_accuracy: 0.8696 - val_loss: 1.5915 - val_precision_3: 0.7778 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 44/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.7729 - loss: 1.8864 - precision_3: 0.6066 - recall_3: 0.9503 - val_accuracy: 0.8696 - val_loss: 1.5981 - val_precision_3: 0.7778 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 45/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.6740 - loss: 1.9905 - precision_3: 0.4864 - recall_3: 0.8435 - val_accuracy: 0.8696 - val_loss: 1.6177 - val_precision_3: 0.7778 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 46/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.6988 - loss: 1.8963 - precision_3: 0.5413 - recall_3: 0.8844 - val_accuracy: 0.7826 - val_loss: 1.6203 - val_precision_3: 0.6667 - val_recall_3: 0.7500 - learning_rate: 3.0000e-04
# Epoch 47/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.7735 - loss: 1.9098 - precision_3: 0.6380 - recall_3: 0.8982 - val_accuracy: 0.7826 - val_loss: 1.6182 - val_precision_3: 0.6667 - val_recall_3: 0.7500 - learning_rate: 3.0000e-04
# Epoch 48/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.7577 - loss: 1.9618 - precision_3: 0.6460 - recall_3: 0.8228 - val_accuracy: 0.8261 - val_loss: 1.6332 - val_precision_3: 0.7000 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 49/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 0.6591 - loss: 2.0512 - precision_3: 0.5045 - recall_3: 0.8133 - val_accuracy: 0.8261 - val_loss: 1.6485 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 50/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.6349 - loss: 2.0923 - precision_3: 0.4683 - recall_3: 0.7947 - val_accuracy: 0.8261 - val_loss: 1.6475 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 51/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.7746 - loss: 1.8261 - precision_3: 0.6284 - recall_3: 0.9168 - val_accuracy: 0.7826 - val_loss: 1.6728 - val_precision_3: 0.6154 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 52/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.7177 - loss: 1.9171 - precision_3: 0.5390 - recall_3: 0.8495 - val_accuracy: 0.8261 - val_loss: 1.6337 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 53/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.7532 - loss: 1.7905 - precision_3: 0.5708 - recall_3: 0.9288 - val_accuracy: 0.8261 - val_loss: 1.5723 - val_precision_3: 0.7000 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 54/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.7461 - loss: 1.8801 - precision_3: 0.5758 - recall_3: 0.8751 - val_accuracy: 0.8696 - val_loss: 1.5590 - val_precision_3: 0.7273 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 55/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.7366 - loss: 1.8179 - precision_3: 0.5832 - recall_3: 0.9151 - val_accuracy: 0.7391 - val_loss: 1.6633 - val_precision_3: 0.6250 - val_recall_3: 0.6250 - learning_rate: 3.0000e-04
# Epoch 56/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - accuracy: 0.6802 - loss: 1.9812 - precision_3: 0.4923 - recall_3: 0.9038 - val_accuracy: 0.8261 - val_loss: 1.5397 - val_precision_3: 0.7500 - val_recall_3: 0.7500 - learning_rate: 3.0000e-04
# Epoch 57/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.8068 - loss: 1.7861 - precision_3: 0.6969 - recall_3: 0.8588 - val_accuracy: 0.7826 - val_loss: 1.5216 - val_precision_3: 0.6364 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 58/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.8223 - loss: 1.6983 - precision_3: 0.6704 - recall_3: 0.9208 - val_accuracy: 0.8261 - val_loss: 1.5522 - val_precision_3: 0.7000 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 59/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 0.8005 - loss: 1.7994 - precision_3: 0.6582 - recall_3: 0.9187 - val_accuracy: 0.8261 - val_loss: 1.6018 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 60/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.7739 - loss: 1.8192 - precision_3: 0.6366 - recall_3: 0.8857 - val_accuracy: 0.8261 - val_loss: 1.5248 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 61/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.7869 - loss: 1.7566 - precision_3: 0.6311 - recall_3: 0.8940 - val_accuracy: 0.8261 - val_loss: 1.5041 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 62/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.8093 - loss: 1.7495 - precision_3: 0.6835 - recall_3: 0.9311 - val_accuracy: 0.8696 - val_loss: 1.4884 - val_precision_3: 0.7273 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 63/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - accuracy: 0.7655 - loss: 1.8022 - precision_3: 0.5794 - recall_3: 0.8724 - val_accuracy: 0.7826 - val_loss: 1.5835 - val_precision_3: 0.6154 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 64/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.8213 - loss: 1.7891 - precision_3: 0.7032 - recall_3: 0.9127 - val_accuracy: 0.7391 - val_loss: 1.6423 - val_precision_3: 0.6000 - val_recall_3: 0.7500 - learning_rate: 3.0000e-04
# Epoch 65/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.7377 - loss: 1.9111 - precision_3: 0.6107 - recall_3: 0.8005 - val_accuracy: 0.8261 - val_loss: 1.6048 - val_precision_3: 0.7500 - val_recall_3: 0.7500 - learning_rate: 3.0000e-04
# Epoch 66/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.7786 - loss: 1.7901 - precision_3: 0.6585 - recall_3: 0.8018 - val_accuracy: 0.8261 - val_loss: 1.5885 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 67/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7656 - loss: 1.7714 - precision_3: 0.5889 - recall_3: 0.9194 - val_accuracy: 0.7826 - val_loss: 1.6163 - val_precision_3: 0.6154 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 68/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.8145 - loss: 1.8747 - precision_3: 0.6820 - recall_3: 0.8981 - val_accuracy: 0.8261 - val_loss: 1.6185 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 69/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.8078 - loss: 1.6878 - precision_3: 0.6420 - recall_3: 0.9609 - val_accuracy: 0.7826 - val_loss: 1.6338 - val_precision_3: 0.6364 - val_recall_3: 0.8750 - learning_rate: 3.0000e-04
# Epoch 70/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.8155 - loss: 1.6846 - precision_3: 0.6571 - recall_3: 0.9583 - val_accuracy: 0.8261 - val_loss: 1.6443 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 71/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8363 - loss: 1.6427 - precision_3: 0.7007 - recall_3: 0.9795 - val_accuracy: 0.8261 - val_loss: 1.7397 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 72/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.7541 - loss: 1.7382 - precision_3: 0.6017 - recall_3: 0.8883 - val_accuracy: 0.8261 - val_loss: 1.7331 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 3.0000e-04
# Epoch 73/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - accuracy: 0.8230 - loss: 1.6642 - precision_3: 0.6819 - recall_3: 0.9140 - val_accuracy: 0.7826 - val_loss: 1.7477 - val_precision_3: 0.6154 - val_recall_3: 1.0000 - learning_rate: 9.0000e-05
# Epoch 74/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.8171 - loss: 1.6871 - precision_3: 0.6586 - recall_3: 0.9661 - val_accuracy: 0.8261 - val_loss: 1.6876 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 9.0000e-05
# Epoch 75/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.8669 - loss: 1.5947 - precision_3: 0.7346 - recall_3: 0.9778 - val_accuracy: 0.8261 - val_loss: 1.6348 - val_precision_3: 0.6667 - val_recall_3: 1.0000 - learning_rate: 9.0000e-05
# ...
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.5885 - loss: 2.2807 - precision_9: 0.4537 - recall_9: 0.8282 - val_accuracy: 0.5652 - val_loss: 1.9278 - val_precision_9: 0.4444 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.6788 - loss: 2.1760 - precision_9: 0.5075 - recall_9: 0.8721 - val_accuracy: 0.5652 - val_loss: 1.9136 - val_precision_9: 0.4444 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.6521 - loss: 2.2625 - precision_9: 0.5102 - recall_9: 0.7653 - val_accuracy: 0.6087 - val_loss: 1.9009 - val_precision_9: 0.4706 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.6307 - loss: 2.2604 - precision_9: 0.4587 - recall_9: 0.7877 - val_accuracy: 0.6522 - val_loss: 1.8963 - val_precision_9: 0.5000 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.6772 - loss: 2.1733 - precision_9: 0.5203 - recall_9: 0.9145 - val_accuracy: 0.6522 - val_loss: 1.8936 - val_precision_9: 0.5000 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 22/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - accuracy: 0.6485 - loss: 2.2051 - precision_9: 0.4591 - recall_9: 0.8057 - val_accuracy: 0.6522 - val_loss: 1.8842 - val_precision_9: 0.5000 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 23/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - accuracy: 0.5889 - loss: 2.2947 - precision_9: 0.4383 - recall_9: 0.8401 - val_accuracy: 0.6957 - val_loss: 1.8724 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 24/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.6413 - loss: 2.1594 - precision_9: 0.4694 - recall_9: 0.7975 - val_accuracy: 0.6957 - val_loss: 1.8587 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 25/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.6208 - loss: 2.2224 - precision_9: 0.4585 - recall_9: 0.7891 - val_accuracy: 0.6957 - val_loss: 1.8501 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 26/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6764 - loss: 2.2488 - precision_9: 0.5099 - recall_9: 0.7972 - val_accuracy: 0.6957 - val_loss: 1.8442 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 27/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 225ms/step - accuracy: 0.6469 - loss: 2.2726 - precision_9: 0.4957 - recall_9: 0.7688 - val_accuracy: 0.6957 - val_loss: 1.8391 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 28/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.6602 - loss: 2.1596 - precision_9: 0.4512 - recall_9: 0.8204 - val_accuracy: 0.6957 - val_loss: 1.8336 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 29/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - accuracy: 0.6538 - loss: 2.1548 - precision_9: 0.4726 - recall_9: 0.8097 - val_accuracy: 0.6957 - val_loss: 1.8302 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 30/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.6514 - loss: 2.2300 - precision_9: 0.4887 - recall_9: 0.8359 - val_accuracy: 0.6957 - val_loss: 1.8281 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 31/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 0.6799 - loss: 2.2334 - precision_9: 0.5621 - recall_9: 0.8182 - val_accuracy: 0.6957 - val_loss: 1.8252 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 32/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.5917 - loss: 2.1797 - precision_9: 0.4173 - recall_9: 0.8346 - val_accuracy: 0.7391 - val_loss: 1.8109 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 33/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6471 - loss: 2.3598 - precision_9: 0.5220 - recall_9: 0.7242 - val_accuracy: 0.7391 - val_loss: 1.8066 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 34/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.6178 - loss: 2.2863 - precision_9: 0.4627 - recall_9: 0.6807 - val_accuracy: 0.6957 - val_loss: 1.8081 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 35/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.6379 - loss: 2.2457 - precision_9: 0.4955 - recall_9: 0.8542 - val_accuracy: 0.6522 - val_loss: 1.8026 - val_precision_9: 0.5000 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 36/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.5552 - loss: 2.2746 - precision_9: 0.3899 - recall_9: 0.8091 - val_accuracy: 0.6522 - val_loss: 1.7959 - val_precision_9: 0.5000 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 37/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.6387 - loss: 2.1823 - precision_9: 0.4891 - recall_9: 0.8098 - val_accuracy: 0.7391 - val_loss: 1.7867 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 38/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.6012 - loss: 2.2458 - precision_9: 0.4257 - recall_9: 0.7080 - val_accuracy: 0.6957 - val_loss: 1.7797 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 39/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.7152 - loss: 2.0589 - precision_9: 0.5509 - recall_9: 0.8845 - val_accuracy: 0.7391 - val_loss: 1.7695 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 40/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.6744 - loss: 2.0870 - precision_9: 0.5180 - recall_9: 0.8310 - val_accuracy: 0.7391 - val_loss: 1.7623 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 41/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 0.6341 - loss: 2.1582 - precision_9: 0.4398 - recall_9: 0.7799 - val_accuracy: 0.7391 - val_loss: 1.7549 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 42/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.6465 - loss: 2.1472 - precision_9: 0.5007 - recall_9: 0.8492 - val_accuracy: 0.7391 - val_loss: 1.7562 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 43/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.6638 - loss: 2.1786 - precision_9: 0.5256 - recall_9: 0.8666 - val_accuracy: 0.6957 - val_loss: 1.7575 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 44/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.6645 - loss: 2.1147 - precision_9: 0.5254 - recall_9: 0.8731 - val_accuracy: 0.6957 - val_loss: 1.7510 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 45/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6537 - loss: 2.0809 - precision_9: 0.4918 - recall_9: 0.8503 - val_accuracy: 0.7391 - val_loss: 1.7495 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 46/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.6344 - loss: 2.1644 - precision_9: 0.4860 - recall_9: 0.7778 - val_accuracy: 0.7391 - val_loss: 1.7496 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 47/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.6558 - loss: 2.1930 - precision_9: 0.4748 - recall_9: 0.8591 - val_accuracy: 0.6957 - val_loss: 1.7484 - val_precision_9: 0.5333 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 48/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - accuracy: 0.6340 - loss: 2.2018 - precision_9: 0.5064 - recall_9: 0.8066 - val_accuracy: 0.7391 - val_loss: 1.7459 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 49/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6914 - loss: 2.1199 - precision_9: 0.5275 - recall_9: 0.8987 - val_accuracy: 0.7391 - val_loss: 1.7402 - val_precision_9: 0.5714 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 50/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - accuracy: 0.6190 - loss: 2.1547 - precision_9: 0.4891 - recall_9: 0.8204 - val_accuracy: 0.7826 - val_loss: 1.7317 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 51/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - accuracy: 0.6336 - loss: 2.1319 - precision_9: 0.4695 - recall_9: 0.7508 - val_accuracy: 0.7826 - val_loss: 1.7273 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 52/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.6928 - loss: 2.1992 - precision_9: 0.5464 - recall_9: 0.8225 - val_accuracy: 0.7826 - val_loss: 1.7322 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 53/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.7401 - loss: 2.0316 - precision_9: 0.6056 - recall_9: 0.8733 - val_accuracy: 0.7826 - val_loss: 1.7270 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 54/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.6611 - loss: 2.2142 - precision_9: 0.5193 - recall_9: 0.7547 - val_accuracy: 0.7826 - val_loss: 1.7232 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 55/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.7201 - loss: 2.0019 - precision_9: 0.5518 - recall_9: 0.8904 - val_accuracy: 0.7826 - val_loss: 1.7250 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 56/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - accuracy: 0.6981 - loss: 2.0306 - precision_9: 0.5460 - recall_9: 0.8811 - val_accuracy: 0.7826 - val_loss: 1.7242 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 57/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - accuracy: 0.7063 - loss: 2.0520 - precision_9: 0.5577 - recall_9: 0.8692 - val_accuracy: 0.8261 - val_loss: 1.7179 - val_precision_9: 0.6667 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 58/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - accuracy: 0.6997 - loss: 2.0711 - precision_9: 0.5449 - recall_9: 0.9208 - val_accuracy: 0.7391 - val_loss: 1.7145 - val_precision_9: 0.5833 - val_recall_9: 0.8750 - learning_rate: 9.0000e-05
# Epoch 59/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.6617 - loss: 2.2548 - precision_9: 0.5317 - recall_9: 0.7446 - val_accuracy: 0.7391 - val_loss: 1.7265 - val_precision_9: 0.5833 - val_recall_9: 0.8750 - learning_rate: 9.0000e-05
# Epoch 60/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.6830 - loss: 2.0520 - precision_9: 0.5579 - recall_9: 0.7958 - val_accuracy: 0.7391 - val_loss: 1.7366 - val_precision_9: 0.5833 - val_recall_9: 0.8750 - learning_rate: 9.0000e-05
# Epoch 61/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.6448 - loss: 2.1214 - precision_9: 0.4677 - recall_9: 0.8646 - val_accuracy: 0.7826 - val_loss: 1.7345 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 62/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.7222 - loss: 2.0378 - precision_9: 0.5667 - recall_9: 0.9018 - val_accuracy: 0.7826 - val_loss: 1.7357 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 63/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.7234 - loss: 2.0442 - precision_9: 0.5646 - recall_9: 0.8562 - val_accuracy: 0.7826 - val_loss: 1.7295 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 64/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - accuracy: 0.6795 - loss: 2.0429 - precision_9: 0.5181 - recall_9: 0.8398 - val_accuracy: 0.7826 - val_loss: 1.7565 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 65/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 0.7317 - loss: 2.0027 - precision_9: 0.5692 - recall_9: 0.8933 - val_accuracy: 0.7826 - val_loss: 1.7761 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 66/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.7127 - loss: 2.0101 - precision_9: 0.5274 - recall_9: 0.8737 - val_accuracy: 0.7826 - val_loss: 1.7876 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 67/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.6974 - loss: 2.0973 - precision_9: 0.5437 - recall_9: 0.8359 - val_accuracy: 0.7826 - val_loss: 1.7587 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 68/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.6702 - loss: 2.0502 - precision_9: 0.4525 - recall_9: 0.8707 - val_accuracy: 0.7826 - val_loss: 1.7264 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 9.0000e-05
# Epoch 69/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.6884 - loss: 2.0731 - precision_9: 0.5223 - recall_9: 0.8058 - val_accuracy: 0.7826 - val_loss: 1.7319 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 70/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 0.6641 - loss: 2.1031 - precision_9: 0.5035 - recall_9: 0.7607 - val_accuracy: 0.7826 - val_loss: 1.7375 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 71/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.7471 - loss: 1.9492 - precision_9: 0.5952 - recall_9: 0.8745 - val_accuracy: 0.7826 - val_loss: 1.7438 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 72/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - accuracy: 0.6834 - loss: 1.9833 - precision_9: 0.5422 - recall_9: 0.8364 - val_accuracy: 0.7826 - val_loss: 1.7415 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 73/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.6834 - loss: 2.0972 - precision_9: 0.5199 - recall_9: 0.8120 - val_accuracy: 0.7826 - val_loss: 1.7371 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 74/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.7137 - loss: 1.9520 - precision_9: 0.5160 - recall_9: 0.9120 - val_accuracy: 0.7826 - val_loss: 1.7305 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 75/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - accuracy: 0.7258 - loss: 2.0026 - precision_9: 0.5654 - recall_9: 0.8314 - val_accuracy: 0.7826 - val_loss: 1.7277 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 76/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.6990 - loss: 1.9906 - precision_9: 0.5127 - recall_9: 0.8376 - val_accuracy: 0.7826 - val_loss: 1.7317 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 77/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.7249 - loss: 1.9786 - precision_9: 0.5629 - recall_9: 0.8850 - val_accuracy: 0.7826 - val_loss: 1.7312 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# Epoch 78/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.7065 - loss: 2.0595 - precision_9: 0.5403 - recall_9: 0.8083 - val_accuracy: 0.7826 - val_loss: 1.7343 - val_precision_9: 0.6154 - val_recall_9: 1.0000 - learning_rate: 2.7000e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77        15
#            1       0.58      0.88      0.70         8
#
#     accuracy                           0.74        23
#    macro avg       0.75      0.77      0.73        23
# weighted avg       0.80      0.74      0.75        23
#
#
# === Cross-Validation Results ===
# Accuracy: 0.7062 (±0.1767)
# Precision: 0.5882 (±0.1786)
# Recall: 0.7750 (±0.1837)
# F1: 0.6585 (±0.1642)
# Auc: 0.7857 (±0.2105)
#
# Model training and evaluation complete. Check the output directory for visualizations.
